# %% [markdown]
# # 📺 Netflix Recommendation System
#
# This is a basic content-based recommendation system built using the **Netflix Movies and TV Shows** dataset. The goal is to help users discover similar titles based on features like title, cast, director, genre, and description.
#
# ## 🔍 Dataset
#
# - **Source:** `netflix_titles.csv`
# - **Columns:** Title, Director, Cast, Country, Release Year, Rating, Duration, Listed In (Genre), Description
#
# ## 🧰 Tools Used
#
# - **Pandas** for data manipulation and loading
#
# ## 📦 Step 1: Load the Dataset
#
# The first step is loading the dataset into a pandas DataFrame:

# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## 🧱 Step 2: Create Textual Representation
#
# To build a content-based recommendation system, we first need to represent each title as a single piece of text that includes relevant metadata such as type, title, director, cast, genres, and description. This function combines all these fields into a structured string format for each row:

# %%
def create_textual_representation (row):
    textual_representation = f"""
Type: {row['type']},
Title: {row['title']},
Director: {row['director']},
Cast: {row['cast']},
Released: {row['release_year']},
Genres: {row["listed_in"]},

Description: {row["description"]}

"""
    return textual_representation

# %%
df["textual_representations"] = df.apply(create_textual_representation , axis=1)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
#
#                              textual_representations
# 0  \nType: Movie,\nTitle: Dick Johnson Is Dead,\n...
# 1  \nType: TV Show,\nTitle: Blood & Water,\nDirec...
# 2  \nType: TV Show,\nTitle: Ganglands,\nDirector:...
# 3  \nType: TV Show,\nTitle: Jailbirds New Orleans...
# 4  \nType: TV Show,\nTitle: Kota Factory,\nDirect...

# %%
print(df.loc[0]["textual_representations"])
# Out:
# Type: Movie,
# Title: Dick Johnson Is Dead,
# Director: Kirsten Johnson,
# Cast: nan,
# Released: 2020,
# Genres: Documentaries,
#
# Description: As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.

# %% [markdown]
# ## 🧠 Step 3: Generate Embeddings with Gemini API
#
# We use the **Gemini Embedding API** to convert each show's textual representation into a numerical vector. These embeddings are 768-dimensional and allow us to compute semantic similarity between shows.
#
# ### ⚙️ Setup
#
# - `FAISS` is used for fast similarity search.
# - Each show is embedded using Gemini's `embedding-001` model.
# - Vectors are stored in a FAISS `IndexFlatL2` index.
#
# **Note:** You must replace the `GEMINI_API_KEY` with your actual API key.

# %%
import faiss
import requests
import numpy as np

dim = 4096
index = faiss.IndexFlatL2(dim)
X = np.zeros((len(df["textual_representations"]),dim),dtype="float32")

# %%
import faiss
import requests
import numpy as np

# Gemini API setup
dim = 768  # Gemini text embeddings are 768-dimensional
index = faiss.IndexFlatL2(dim)
X = np.zeros((len(df["textual_representations"]), dim), dtype="float32")

# Gemini API configuration
GEMINI_API_KEY = "GEMINI_API_KEY"  # Replace with your actual API key
GEMINI_API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/embedding-001:embedContent?key={GEMINI_API_KEY}"

def get_embedding(text):
    payload = {
        "model": "models/embedding-001",
        "content": {
            "parts": [{"text": text}]
        }
    }
    
    headers = {
        "Content-Type": "application/json"
    }
    
    try:
        response = requests.post(GEMINI_API_URL, headers=headers, json=payload)
        if response.status_code == 200:
            result = response.json()
            embedding = result["embedding"]["values"]
            return embedding
        else:
            print(f"Error: {response.status_code}, {response.text}")
            return None
    except Exception as e:
        print(f"Request failed: {e}")
        return None

# Your loop
for i, representation in enumerate(df['textual_representations']):
    if i % 30 == 0:
        print(f'Processed {i}/{len(df)} instances')
    
    embedding = get_embedding(representation)
    if embedding is not None:
        embedding_array = np.array(embedding, dtype=np.float32)
        if len(embedding_array) == dim:
            X[i] = embedding_array
        else:
            print(f"Warning: Embedding dimension mismatch at index {i}. Expected {dim}, got {len(embedding_array)}")
    else:
        print(f"Failed to get embedding for index {i}")

index.add(X)
print(f"Index now contains {index.ntotal} vectors")
# Out:
# Processed 0/8807 instances
# Processed 30/8807 instances
# Processed 60/8807 instances
# Processed 90/8807 instances
# Processed 120/8807 instances
# Processed 150/8807 instances
# Processed 180/8807 instances
# Processed 210/8807 instances
# Processed 240/8807 instances
# Processed 270/8807 instances
# Processed 300/8807 instances
# Processed 330/8807 instances
# Processed 360/8807 instances
# Processed 390/8807 instances
# Processed 420/8807 instances
# Processed 450/8807 instances
# Processed 480/8807 instances
# Processed 510/8807 instances
# Processed 540/8807 instances
# Processed 570/8807 instances
# Processed 600/8807 instances
# Processed 630/8807 instances
# Processed 660/8807 instances
# Processed 690/8807 instances
# Processed 720/8807 instances
# Processed 750/8807 instances
# Processed 780/8807 instances
# Processed 810/8807 instances
# Processed 840/8807 instances
# Processed 870/8807 instances
# Processed 900/8807 instances
# Processed 930/8807 instances
# Processed 960/8807 instances
# Processed 990/8807 instances
# Processed 1020/8807 instances
# Processed 1050/8807 instances
# Processed 1080/8807 instances
# Processed 1110/8807 instances
# Processed 1140/8807 instances
# Processed 1170/8807 instances
# Processed 1200/8807 instances
# Processed 1230/8807 instances
# Processed 1260/8807 instances
# Processed 1290/8807 instances
# Processed 1320/8807 instances
# Processed 1350/8807 instances
# Processed 1380/8807 instances
# Processed 1410/8807 instances
# Processed 1440/8807 instances
# Processed 1470/8807 instances
# Processed 1500/8807 instances
# Processed 1530/8807 instances
# Processed 1560/8807 instances
# Processed 1590/8807 instances
# Processed 1620/8807 instances
# Processed 1650/8807 instances
# Processed 1680/8807 instances
# Processed 1710/8807 instances
# Processed 1740/8807 instances
# Processed 1770/8807 instances
# Processed 1800/8807 instances
# Processed 1830/8807 instances
# Processed 1860/8807 instances
# Processed 1890/8807 instances
# Processed 1920/8807 instances
# Processed 1950/8807 instances
# Processed 1980/8807 instances
# Processed 2010/8807 instances
# Processed 2040/8807 instances
# Processed 2070/8807 instances
# Processed 2100/8807 instances
# Processed 2130/8807 instances
# Processed 2160/8807 instances
# Processed 2190/8807 instances
# Processed 2220/8807 instances
# Processed 2250/8807 instances
# Processed 2280/8807 instances
# Processed 2310/8807 instances
# Processed 2340/8807 instances
# Processed 2370/8807 instances
# Processed 2400/8807 instances
# Processed 2430/8807 instances
# Processed 2460/8807 instances
# Processed 2490/8807 instances
# Processed 2520/8807 instances
# Processed 2550/8807 instances
# Processed 2580/8807 instances
# Processed 2610/8807 instances
# Processed 2640/8807 instances
# Processed 2670/8807 instances
# Processed 2700/8807 instances
# Processed 2730/8807 instances
# Processed 2760/8807 instances
# Processed 2790/8807 instances
# Processed 2820/8807 instances
# Processed 2850/8807 instances
# Processed 2880/8807 instances
# Processed 2910/8807 instances
# Processed 2940/8807 instances
# Processed 2970/8807 instances
# Processed 3000/8807 instances
# Processed 3030/8807 instances
# Processed 3060/8807 instances
# Processed 3090/8807 instances
# Processed 3120/8807 instances
# Processed 3150/8807 instances
# Processed 3180/8807 instances
# Processed 3210/8807 instances
# Processed 3240/8807 instances
# Processed 3270/8807 instances
# Processed 3300/8807 instances
# Processed 3330/8807 instances
# Processed 3360/8807 instances
# Processed 3390/8807 instances
# Processed 3420/8807 instances
# Processed 3450/8807 instances
# Processed 3480/8807 instances
# Processed 3510/8807 instances
# Processed 3540/8807 instances
# Processed 3570/8807 instances
# Processed 3600/8807 instances
# Processed 3630/8807 instances
# Processed 3660/8807 instances
# Processed 3690/8807 instances
# Processed 3720/8807 instances
# Processed 3750/8807 instances
# Processed 3780/8807 instances
# Processed 3810/8807 instances
# Processed 3840/8807 instances
# Processed 3870/8807 instances
# Processed 3900/8807 instances
# Processed 3930/8807 instances
# Processed 3960/8807 instances
# Processed 3990/8807 instances
# Processed 4020/8807 instances
# Processed 4050/8807 instances
# Processed 4080/8807 instances
# Processed 4110/8807 instances
# Processed 4140/8807 instances
# Processed 4170/8807 instances
# Processed 4200/8807 instances
# Processed 4230/8807 instances
# Processed 4260/8807 instances
# Processed 4290/8807 instances
# Processed 4320/8807 instances
# Processed 4350/8807 instances
# Processed 4380/8807 instances
# Processed 4410/8807 instances
# Processed 4440/8807 instances
# Processed 4470/8807 instances
# Processed 4500/8807 instances
# Processed 4530/8807 instances
# Processed 4560/8807 instances
# Processed 4590/8807 instances
# Processed 4620/8807 instances
# Processed 4650/8807 instances
# Processed 4680/8807 instances
# Processed 4710/8807 instances
# Processed 4740/8807 instances
# Processed 4770/8807 instances
# Processed 4800/8807 instances
# Processed 4830/8807 instances
# Processed 4860/8807 instances
# Processed 4890/8807 instances
# Processed 4920/8807 instances
# Processed 4950/8807 instances
# Processed 4980/8807 instances
# Processed 5010/8807 instances
# Processed 5040/8807 instances
# Processed 5070/8807 instances
# Processed 5100/8807 instances
# Processed 5130/8807 instances
# Processed 5160/8807 instances
# Processed 5190/8807 instances
# Processed 5220/8807 instances
# Processed 5250/8807 instances
# Processed 5280/8807 instances
# Processed 5310/8807 instances
# Processed 5340/8807 instances
# Processed 5370/8807 instances
# Processed 5400/8807 instances
# Processed 5430/8807 instances
# Processed 5460/8807 instances
# Processed 5490/8807 instances
# Processed 5520/8807 instances
# Processed 5550/8807 instances
# Processed 5580/8807 instances
# Processed 5610/8807 instances
# Processed 5640/8807 instances
# Processed 5670/8807 instances
# Processed 5700/8807 instances
# Processed 5730/8807 instances
# Processed 5760/8807 instances
# Processed 5790/8807 instances
# Processed 5820/8807 instances
# Processed 5850/8807 instances
# Processed 5880/8807 instances
# Processed 5910/8807 instances
# Processed 5940/8807 instances
# Processed 5970/8807 instances
# Processed 6000/8807 instances
# Processed 6030/8807 instances
# Processed 6060/8807 instances
# Processed 6090/8807 instances
# Processed 6120/8807 instances
# Processed 6150/8807 instances
# Processed 6180/8807 instances
# Processed 6210/8807 instances
# Processed 6240/8807 instances
# Processed 6270/8807 instances
# Processed 6300/8807 instances
# Processed 6330/8807 instances
# Processed 6360/8807 instances
# Processed 6390/8807 instances
# Processed 6420/8807 instances
# Processed 6450/8807 instances
# Processed 6480/8807 instances
# Processed 6510/8807 instances
# Processed 6540/8807 instances
# Processed 6570/8807 instances
# Processed 6600/8807 instances
# Processed 6630/8807 instances
# Processed 6660/8807 instances
# Processed 6690/8807 instances
# Processed 6720/8807 instances
# Processed 6750/8807 instances
# Processed 6780/8807 instances
# Processed 6810/8807 instances
# Processed 6840/8807 instances
# Processed 6870/8807 instances
# Processed 6900/8807 instances
# Processed 6930/8807 instances
# Processed 6960/8807 instances
# Processed 6990/8807 instances
# Processed 7020/8807 instances
# Error: 502, <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 502 (Server Error)!!1</title>
#   <style>
#     *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}
#   </style>
#   <a href=//www.google.com/><span id=logo aria-label=Google></span></a>
#   <p><b>502.</b> <ins>That’s an error.</ins>
#   <p>The server encountered a temporary error and could not complete your request.<p>Please try again in 30 seconds.  <ins>That’s all we know.</ins>
#
# Failed to get embedding for index 7048
# Processed 7050/8807 instances
# Processed 7080/8807 instances
# Processed 7110/8807 instances
# Processed 7140/8807 instances
# Processed 7170/8807 instances
# Processed 7200/8807 instances
# Processed 7230/8807 instances
# Processed 7260/8807 instances
# Processed 7290/8807 instances
# Processed 7320/8807 instances
# Processed 7350/8807 instances
# Processed 7380/8807 instances
# Processed 7410/8807 instances
# Processed 7440/8807 instances
# Processed 7470/8807 instances
# Processed 7500/8807 instances
# Processed 7530/8807 instances
# Processed 7560/8807 instances
# Processed 7590/8807 instances
# Processed 7620/8807 instances
# Processed 7650/8807 instances
# Processed 7680/8807 instances
# Processed 7710/8807 instances
# Processed 7740/8807 instances
# Processed 7770/8807 instances
# Processed 7800/8807 instances
# Processed 7830/8807 instances
# Processed 7860/8807 instances
# Processed 7890/8807 instances
# Processed 7920/8807 instances
# Processed 7950/8807 instances
# Processed 7980/8807 instances
# Processed 8010/8807 instances
# Processed 8040/8807 instances
# Processed 8070/8807 instances
# Processed 8100/8807 instances
# Processed 8130/8807 instances
# Processed 8160/8807 instances
# Processed 8190/8807 instances
# Processed 8220/8807 instances
# Processed 8250/8807 instances
# Processed 8280/8807 instances
# Processed 8310/8807 instances
# Processed 8340/8807 instances
# Processed 8370/8807 instances
# Processed 8400/8807 instances
# Processed 8430/8807 instances
# Processed 8460/8807 instances
# Processed 8490/8807 instances
# Processed 8520/8807 instances
# Processed 8550/8807 instances
# Processed 8580/8807 instances
# Processed 8610/8807 instances
# Processed 8640/8807 instances
# Processed 8670/8807 instances
# Processed 8700/8807 instances
# Processed 8730/8807 instances
# Processed 8760/8807 instances
# Processed 8790/8807 instances
# Index now contains 8807 vectors

# %% [markdown]
# ## 💾 Step 4: Save the FAISS Index
#
# After building the FAISS index with all the vector embeddings, we save it to disk so it can be reused without recomputing the embeddings.

# %%
faiss.write_index(index,"index")

# %% [markdown]
# ## 📂 Step 5: Load the FAISS Index
#
# To perform recommendations without rebuilding the entire index, we can load the saved FAISS index from disk using `faiss.read_index()`.

# %%
index = faiss.read_index('index')

# %%
favorite_movie = df.iloc[1358]

# %% [markdown]
# ## 🎯 Step 6: Recommend Similar Titles
#
# To recommend similar shows or movies:
#
# 1. Use **Gemini** to embed the favorite movie's textual representation.
# 2. Perform a **vector similarity search** using FAISS.
# 3. Retrieve and display the top 5 similar titles.

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyA2Umg0zYQAqCIQxyPJYCD5cgZjqpodEZg")

# Use genai.embed_content() directly, not model.embed_content()
response = genai.embed_content(
    model="models/embedding-001",
    content=favorite_movie['textual_representations'],
    task_type="retrieval_document"  # or "retrieval_query", etc.
)

# Access the embedding from the response
embedding = response['embedding']
embedding = np.array([response["embedding"]],dtype="float32")

# %%
D, I = index.search(embedding,5)
best_matches = np.array(df["textual_representations"])[(I.flatten())]
for match in best_matches:
    print("Next Movie:")
    print(match)
    print("--------------------------------------------------------------------------")
# Out:
# Next Movie:
#
# Type: Movie,
# Title: Shutter Island,
# Director: Martin Scorsese,
# Cast: Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley, Max von Sydow, Michelle Williams, Emily Mortimer, Patricia Clarkson, Jackie Earle Haley, Ted Levine, John Carroll Lynch, Elias Koteas,
# Released: 2010,
# Genres: Thrillers,
#
# Description: A U.S. marshal's troubling visions compromise his investigation into the disappearance of a patient from a hospital for the criminally insane.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: The Departed,
# Director: Martin Scorsese,
# Cast: Leonardo DiCaprio, Matt Damon, Jack Nicholson, Mark Wahlberg, Martin Sheen, Ray Winstone, Vera Farmiga, Anthony Anderson, Alec Baldwin, Kevin Corrigan,
# Released: 2006,
# Genres: Dramas, Thrillers,
#
# Description: Two rookie Boston cops are sent deep undercover – one inside the gang of a charismatic Irish mob boss and the other double-crossing his own department.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: The Lake House,
# Director: Alejandro Agresti,
# Cast: Keanu Reeves, Sandra Bullock, Dylan Walsh, Shohreh Aghdashloo, Ebon Moss-Bachrach, Lynn Collins, Willeke van Ammelrooy, Christopher Plummer,
# Released: 2006,
# Genres: Dramas, Romantic Movies, Sci-Fi & Fantasy,
#
# Description: A lonely doctor begins writing letters to the frustrated architect who lives in her former home, only to discover that they're living two years apart.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: Stonehearst Asylum,
# Director: Brad Anderson,
# Cast: Kate Beckinsale, Jim Sturgess, David Thewlis, Brendan Gleeson, Ben Kingsley, Michael Caine, Jason Flemyng, Sophie Kennedy Clark, Sinéad Cusack, Edmund Kingsley,
# Released: 2014,
# Genres: Horror Movies, Thrillers,
#
# Description: In 1899, a young doctor arrives at an asylum for an apprenticeship and becomes suspicious of his mentor's methods while falling for a female patient.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: The Informant!,
# Director: Steven Soderbergh,
# Cast: Matt Damon, Scott Bakula, Joel McHale, Melanie Lynskey, Thomas F. Wilson, Patton Oswalt, Tony Hale, Eddie Jemison, Paul F. Tompkins, Tom Papa,
# Released: 2009,
# Genres: Comedies, Dramas,
#
# Description: While gathering evidence against his employer to help the FBI build a price-fixing case, Mark Whitacre begins to piece together a fantasy world.
#
#
# --------------------------------------------------------------------------

# %% [markdown]
# ## 🎬 Step 7: Test the Recommender with a Custom Movie
#
# Instead of selecting from the dataset, we can manually input a movie description and find similar titles. Here we test the system using the movie **IT (2017)**

# %%
test_movie = f"""
Type: 'Movie',
Title: 'IT',
Director: Andy Muschietti,
Cast: 'Bill Skarsgard , Jaeden Martell , Finn Wolfhard',
Released: '2017',
Genres: 'Monster Horror , Horror',

Description: 'In the summer of 1989, a group of bullied kids band together to destroy a shape-shifting monster, which disguises itself as a clown and preys on the children of Derry, their small Maine town.'
"""

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyA2Umg0zYQAqCIQxyPJYCD5cgZjqpodEZg")

# Use genai.embed_content() directly, not model.embed_content()
response = genai.embed_content(
    model="models/embedding-001",
    content=test_movie,
    task_type="retrieval_document"  # or "retrieval_query", etc.
)

# Access the embedding from the response
embedding = response['embedding']
embedding = np.array([response["embedding"]],dtype="float32")

D, I = index.search(embedding,5)
best_matches = np.array(df["textual_representations"])[(I.flatten())]
for match in best_matches:
    print("Next Movie:")
    print(match)
    print("--------------------------------------------------------------------------")
# Out:
# Next Movie:
#
# Type: Movie,
# Title: Hubie Halloween,
# Director: Steve Brill,
# Cast: Adam Sandler, Kevin James, Julie Bowen, Ray Liotta, Steve Buscemi, Maya Rudolph, Rob Schneider, June Squibb, Kenan Thompson, Tim Meadows, Michael Chiklis, Karan Brar, George Wallace, Paris Berelc, Noah Schnapp, China Anne McClain, Colin Quinn, Kym Whitley, Lavell Crawford, Mikey Day, Jackie Sandler, Sadie Sandler, Sunny Sandler,
# Released: 2020,
# Genres: Comedies, Horror Movies,
#
# Description: Hubie's not the most popular guy in Salem, Mass., but when Halloween turns truly spooky, this good-hearted scaredy-cat sets out to keep his town safe.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: House of the Witch,
# Director: Alex Merkin,
# Cast: Emily Bader, Darren Mann, Michelle Randolph, Coy Stewart, Jesse Pepe, Arden Belle, Joel Nagle, Nolan Bateman,
# Released: 2017,
# Genres: Horror Movies,
#
# Description: A group of daring teens finds themselves in a fight for their lives inside a haunted house when a sinister spirit crashes their Halloween party.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: Child's Play,
# Director: Tom Holland,
# Cast: Catherine Hicks, Alex Vincent, Brad Dourif, Chris Sarandon, Dinah Manoff, Tommy Swerdlow, Jack Colvin, Neil Giuntoli, Juan Ramírez, Alan Wilder,
# Released: 1988,
# Genres: Cult Movies, Horror Movies,
#
# Description: When a rash of murders unfolds, 6-year-old Andy knows that his toy doll Chucky is the killer, but neither his mom nor the cops believe him.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: The Devil All The Time,
# Director: Antonio Campos,
# Cast: Tom Holland, Bill Skarsgård, Riley Keough, Robert Pattinson, Mia Wasikowska, Jason Clarke, Sebastian Stan, Haley Bennett, Harry Melling, Eliza Scanlen,
# Released: 2020,
# Genres: Dramas, Thrillers,
#
# Description: Sinister characters converge around a young man devoted to protecting those he loves in a postwar backwoods town teeming with corruption and brutality.
#
#
# --------------------------------------------------------------------------
# Next Movie:
#
# Type: Movie,
# Title: Monster House,
# Director: Gil Kenan,
# Cast: Mitchel Musso, Sam Lerner, Spencer Locke, Steve Buscemi, Kathleen Turner, Jason Lee, Jon Heder, Maggie Gyllenhaal, Catherine O'Hara, Fred Willard, Nick Cannon, Kevin James,
# Released: 2006,
# Genres: Children & Family Movies, Comedies,
#
# Description: A trio of friends sets out to expose the terrors of a vacant neighborhood house, which appears to have a craving for people — and a life of its own.
#
#
# --------------------------------------------------------------------------
